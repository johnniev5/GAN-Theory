# %% [markdown]
# ![policy.png](attachment:policy.png)
# ![update.png](attachment:update.png)
#
# reward一般建议有正，有负，如果实际都得到正，那应该人为设计为正负...
#
# ![maximum%20likelihood%20vs%20RL.png](attachment:maximum%20likelihood%20vs%20RL.png)
#
# RL中人给feedback，而人为定的reward，也是不精准的，另外，这就需要多次的人机互动，这也不是很现实...
#
# 而引入GAN后，只是将判别器替换掉人为判定...
#
# ![%E7%AE%97%E6%B3%95.png](attachment:%E7%AE%97%E6%B3%95.png)
# ![%E6%97%A0%E6%B3%95%E5%BE%AE%E5%88%86.png](attachment:%E6%97%A0%E6%B3%95%E5%BE%AE%E5%88%86.png)
#
# 输入到判别器中的不是sampling出的数据，因为是无法微分的，就改用输入一个分布，但是输入分布使用GAN的时候，是train不起来的，但可以选用WGAN...
#
# ![continuous%20input.png](attachment:continuous%20input.png)
# ![wgan%20can%20help.png](attachment:wgan%20can%20help.png)
#
# 另一种方法就是结合RL，如下：
#
# ![RL.png](attachment:RL.png)
#
# 结合RL可能的问题，可行的解决方法：
#
# ![possible%20way.png](attachment:possible%20way.png)
#
# ![RankGAN.png](attachment:RankGAN.png)
#
# 最大化似然，用的是平均，GAN的效果相对较好...
#
# ![MLE%20vs%20GAN.png](attachment:MLE%20vs%20GAN.png)
#
# ![summaries.png](attachment:summaries.png)
