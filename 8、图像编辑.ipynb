# %% [markdown]
# 反推图片的某个特征，就能够通过某个维度进行修改... 通过计算某几个特征各自的平均值，差向量，即为从某个特征到某个特征的距离向量...
#
# 这个思路，其实就是得到某个结果，想知道是通过那个获得的，不同于自编码器的直接产生结果...
#
# ![pic%20transform.png](attachment:pic%20transform.png)
# ![minima%20function.png](attachment:minima%20function.png)
# ![image%20super%20resolution.png](attachment:image%20super%20resolution.png)
#
# image completion...
#
# 这种方法对于图像，物体修复等很有帮助...
